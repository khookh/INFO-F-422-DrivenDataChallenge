# %% [markdown]
# # Gradient Boosting classifier with decision trees
#
# Gradient boosting is an ensemble learning technique that consists of sequentially adding predictors. Each predictor will fit on the residual error of the previous predictor.
#
# The predictors used in this case are weak learners decision trees.

# %%
library(gbm)
# Out:
# Loaded gbm 2.1.8

# %%
column_to_drop<-c("X.1","X")
training_set <- read.csv("../Data/PreProcess/processed_training_data_split.csv") # load training set
validation_set <- read.csv("../Data/PreProcess/processed_verification_data_split.csv") # load validation set

# Dropped "X.1","X" because they just represent the row numbers
training_set<-training_set[,!(names(validation_set) %in% column_to_drop)] # drop the desired columns on validation set
validation_set<-validation_set[,!(names(validation_set) %in% column_to_drop)] # drop the desired columns on validation set

# %%
gradient.boost.model <- gbm(id ~ ., data=training_set, n.trees=10000, shrinkage=0.1, interaction.depth=3, distribution="gaussian")
# Out:
# Warning message in gbm.fit(x = x, y = y, offset = offset, distribution = distribution, :
# “NAs introduits lors de la conversion automatique”

# %%
gradient.boost.model
# Out:
# gbm(formula = id ~ ., distribution = "gaussian", data = training_set,
#     n.trees = 10000, interaction.depth = 3, shrinkage = 0.1)
# A gradient boosted model with gaussian loss function.
# 10000 iterations were performed.
# There were 80 predictors of which 0 had non-zero influence.

# %%
gbm.predict <- predict(gradient.boost.model, validation_set)
# Out:
# Using 10000 trees...

# %%
gbm.predict
# Out:
#     [1] NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA
#    [25] NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA
#    [49] NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA
#    [73] NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA
#    [97] NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA
#   [121] NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA
#   [145] NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA
#   [169] NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA
#   [193] NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA
#   [217] NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA
#   [241] NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA
#   [265] NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA
# ...

# %%
library(caret)
conf <- confusionMatrix(data=gdm.predict, reference = factor(validation_set$id)) # GBM confusion matri
conf
# Out:
# Error in confusionMatrix(data = gdm.predict, reference = factor(validation_set$id)): objet 'gdm.predict' introuvable
# Traceback:
#
# 1. confusionMatrix(data = gdm.predict, reference = factor(validation_set$id))
